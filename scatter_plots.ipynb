# %% [markdown]
# # Machine Learning
# - It is of 2 types
#     1. Supervised learning
#     2. Unsupervised learning

# %%
# Import the workspace and convert data set to data frame
from azureml import Workspace
ws = Workspace()
experiment = ws.experiments['3e03112c782b4692b6cd6e9747f87737.f-id.421951a1ecd54337a2bc9ff05fbaee55']
ds = experiment.get_intermediate_dataset(
    node_id='f6f20b1c-1c1c-4157-9527-bb8301f630cc-78',
    port_name='Results dataset',
    data_type_id='GenericCSV'
)
frame = ds.to_dataframe()

# %%
frame
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68     190      94        29         105       40.8
# 1      14861698  female   20     166      60        14          94       40.3
# 2      11179863    male   69     179      79         5          88       38.7
# 3      16180408  female   34     179      71        13         100       40.5
# 4      17771927  female   27     154      58        10          81       39.8
# 5      15130815  female   36     151      50        23          96       40.7
# 6      19602372  female   33     158      56        22          95       40.5
# 7      11117088    male   41     175      85        25         100       40.7
# 8      12132339    male   60     186      94        21          97       40.4
# 9      17964668  female   26     146      51        16          90       40.2
# 10     13723164  female   36     177      76         1          74       37.8
# ...

# %% [markdown]
# # Scatter plot Matrix

# %%
# Create a scatter plot matrix
# %matplotlib inline

import seaborn as sns
num_cols = ["Age", "Height", "Weight", "Duration",
            "Heart_Rate", "Body_Temp", "Calories"] 
sns.pairplot(frame[num_cols], size=2)
# Out:
# /home/nbuser/anaconda3_23/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/nbuser/anaconda3_23/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/nbuser/anaconda3_23/lib/python3.4/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
